# %% [markdown]
# ## Lighthouse Labs
# ### W07D2 Deployment of ML Models
#
# Instructor: Sabya DG
#
# Credit: [Socorro Dominguez](https://github.com/sedv8808/LighthouseLabs/tree/main/W07D2)

# %% [markdown]
# **Agenda:**
#
# * Review: REST APIs
# * Intro to Flask
#     * Flask for API creation
# * Tmux

# %% [markdown]
# ## How is Data Science related to the Web?

# %% [markdown]
# Web Pages are intended for Humans. However, there’s lots of valuable data embedded in web pages:
# * course listings
# * bank records
# * blogs

# %% [markdown]
# ### What if we wanted to collect this data for analysis?

# %% [markdown]
# We would need a program that acts like a web browser but collects web document data rather than displaying it.
#
# This is called `web scraping`. Popular methods include Scrapy, a free and open-source web-crawling framework written in Python.

# %% [markdown]
# A Web Scraper...
# * acts like a web browser (i.e., sends HTTP GET requests to web server)
# * at the time it allows your to process the data that comes back.
#
# Some other useful libraries useful when scraping if you are interested:
#
# Beautiful Soup
# * python library that can parse HTML (Super useful)

# %% [markdown]
# ### Disadvantages of Web Scraping
#
# - Scraping processes are hard to understand.
#
# - Extracted data needs extensive cleaning (This is where we use `Beautiful Soup`).
#
# - In certain cases, this might take a long time and a lot of energy to complete (show why)
#
# - New data extraction applications a lot of time in the beginning.
#
# - Web scrapping services are slower than API calls.
#
# - If the developer of a website decides to introduce changes in the code, the scrapping service might stop working.

# %% [markdown]
# # Super Easy Example of Web Scraping

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_current_heads_of_state_and_government

# %%
URL = "https://en.wikipedia.org/wiki/List_of_current_heads_of_state_and_government"

# %%
res = requests.get(URL).text
res
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of current heads of state and government - Wikipedia</title>\n<script>document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled";(function(){var cookie=document.cookie.match(/(?:^|; )enwikimwclientprefs=([^;]+)/);if(cookie){var featureName=cookie[1];document.documentElement.className=document.documentElement.className.replace(featureName+\'-enabled\',featureName+\'-disabled\');}}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"3622558b-1626-4318-b2e1-47e775a97380",\n"wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_current_heads_of_state_and_government","wgTitle":"List of current heads of state and government","wgCurRevisionId":1142054737,"wgRevisionId":1142054737,"wgArticleId":380398,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Wikipedia indefinitely semi-protected pages","Articles with Spanish-language sources (es)","Articles with Italian-language sources (it)","Use dmy dates from January 2016","Use British English from January 2016","Lists of current office-holders","Lists of heads of state","Lists of heads of government","2020s in politics","Contemporary history"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"List_of_current_heads_of_state_and_government","wgRelevantArticleId":380398,\n"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":60000,"wgNoticeProject":"wikipedia","wgVector2022PreviewPages":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q1023630","GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false};RLSTATE={\n"skins.vector.user.styles":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","skins.vector.user":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","mediawiki.ui.button":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","mediawiki.ui.icon":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wik ...

# %%
soup = BeautifulSoup(res,'lxml')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
res = requests.get(URL).text
soup = BeautifulSoup(res,'lxml')
for items in soup.find('table', class_='wikitable').find_all('tr')[1::1]:
    data = items.find_all(['th','td'])
    try:
        country = data[0].a.text
        title = data[1].a.text
        try:
            name = data[1].a.find_next_sibling().text
        except:
            pass
    except IndexError:
        pass
                
    print("{}|{}|{}".format(country,title,name))
# Out:
# Afghanistan|Supreme Leader|Hibatullah Akhundzada
# Albania|President|Bajram Begaj
# Algeria|President|Abdelmadjid Tebboune
# Andorra|Episcopal Co-Prince|Joan Enric Vives i Sicília
# Angola|President|João Lourenço
# Antigua and Barbuda|King|Charles III
# Argentina|President|Alberto Fernández
# Armenia|President|Vahagn Khachaturyan
# Australia|King|Charles III
# Austria|President|Alexander Van der Bellen
# Azerbaijan|President|Ilham Aliyev
# Bahamas, The|King|Charles III
# Bahrain|King|Hamad bin Isa Al Khalifa
# Bangladesh|President|Mohammad Abdul Hamid
# Barbados|President|Sandra Mason
# Belarus|President|Alexander Lukashenko
# Belgium|King|Philippe
# Belize|King|Charles III
# Benin|President|Patrice Talon
# Bhutan|King|Jigme Khesar Namgyel Wangchuck
# Bolivia|President|Luis Arce
# Bosnia and Herzegovina|High Representative|Christian Schmidt
# Presidency|Prime Minister|Borjana Krišto
# Željka Cvijanović|Prime Minister|Borjana Krišto
# Denis Bećirović|Prime Minister|Borjana Krišto
# Botswana|President|Mokgweetsi Masisi
# Brazil|President|Luiz Inácio Lula da Silva
# Brunei|Sultan|Prime Minister
# Bulgaria|President|Rumen Radev
# Burkina Faso|Patriotic Movement for Safeguard and Restoration|Ibrahim Traoré
# President|Prime Minister|Apollinaire Kyélem
# Burundi|President|Évariste Ndayishimiye
# Cambodia|King|Norodom Sihamoni
# Cameroon|President|Paul Biya
# Canada|King|Charles III
# Cape Verde|President|José Maria Neves
# Central African Republic|President|Faustin-Archange Touadéra
# Chad|President|Mahamat Déby
# Chile|President|Gabriel Boric
# China|General Secretary of the Communist Party|Xi Jinping
# President|Premier|Li Keqiang
# Colombia|President|Gustavo Petro
# Comoros|President|Azali Assoumani
# Congo, Democratic Republic of the|President|Félix Tshisekedi
# Congo, Republic of the|President|Denis Sassou Nguesso
# Costa Rica|President|Rodrigo Chaves Robles
# Croatia|President|Zoran Milanović
# Cuba|First Secretary of the Communist Party|Miguel Díaz-Canel
# President|Prime Minister|Manuel Marrero Cruz
# Cyprus|President|Nicos Anastasiades
# Nikos Christodoulides|President|Nicos Anastasiades
# Czech Republic|President|Miloš Zeman
# Denmark|Queen|Margrethe II
# Djibouti|President|Ismaïl Omar Guelleh
# Dominica|President|Charles Savarin
# Dominican Republic|President|Luis Abinader
# East Timor|President|José Ramos-Horta
# Ecuador|President|Guillermo Lasso
# Egypt|President|Abdel Fattah el-Sisi
# El Salvador|President|Nayib Bukele
# Equatorial Guinea|President|Teodoro Obiang Nguema Mbasogo
# Eritrea|People's Front for Democracy and Justice|Isaias Afwerki
# President|People's Front for Democracy and Justice|Isaias Afwerki
# Estonia|President|Alar Karis
# Eswatini|King|Mswati III
# Queen Mother|King|Mswati III
# Ethiopia|President|Sahle-Work Zewde
# Fiji|President|Wiliame Katonivere
# Finland|President|Sauli Niinistö
# France|President|Emmanuel Macron
# Gabon|President|Ali Bongo Ondimba
# Gambia, The|President|Adama Barrow
# Georgia|President|Salome Zourabichvili
# Germany|President|Frank-Walter Steinmeier
# Ghana|President|Nana Akufo-Addo
# Greece|President|Katerina Sakellaropoulou
# Grenada|King|Charles III
# Guatemala|President|Alejandro Giammattei
# Guinea|National Committee of Reconciliation and Development|Mamady Doumbouya
# President|Prime Minister|Bernard Gomou
# Guinea-Bissau|President|Umaro Sissoco Embaló
# Guyana|President|Irfaan Ali
# Haiti|President|Vacant
# Honduras|President|Xiomara Castro
# Hungary|President|Katalin Novák
# Iceland|President|Guðni Th. Jóhannesson
# India|President|Droupadi Murmu
# Indonesia|President|Joko Widodo
# Iran|Supreme Leader|Ali Khamenei
# Iraq|President|Abdul Latif Rashid
# Ireland|President|Michael D. Higgins
# Israel|President|Isaac Herzog
# Italy|President|Sergio Mattarella
# Ivory Coast|President|Alassane Ouattara
# Jamaica|King|Charles III
# Japan|Emperor|Naruhito
# Jordan|King|Abdullah II
# Kazakhstan|President|Qasym-Zhomart Toqaev
# Kenya|President|William Ruto
# Kiribati|President|Taneti Maamau
# Kuwait|Emir|Nawaf Al-Ahmad Al-Jaber Al-Sabah
# Kyrgyzstan|President|Sadyr Japarov
# Laos|General Secretary of the People's Revolutionary Party|Thongloun Sisoulith
# President|Prime Minister|Sonexay Siphandone
# Latvia|President|Egils Levits
# Lebanon|President|Vacant
# Lesotho|King|Letsie III
# Liberia|President|George Weah
# Libya|Chairman|Presidential Council
# Liechtenstein|Prince Regnant|Hans-Adam II
# Regent|Prince Regnant|Hans-Adam II
# Lithuania|President|Gitanas Nausėda
# Luxembourg|Grand Duke|Henri
# Madagascar|President|Andry Rajoelina
# Malawi|President|Lazarus Chakwera
# Malaysia|Yang di-Pertuan Agong|Abdullah Sultan Ahmad Shah
# Maldives|President|Ibrahim Mohamed Solih
# Mali|President|Assimi Goïta
# Malta|President|George Vella
# Marshall Islands|President|David Kabua
# Mauritania|President|Mohamed Ould Ghazouani
# Mauritius|President|Prithvirajsing Roopun
# Mexico|President|Andrés Manuel López Obrador
# Federated States of Micronesia|President|David Panuelo
# Moldova|President|Maia Sandu
# Monaco|Sovereign Prince|Albert II
# Mongolia|President|Ukhnaagiin Khürelsükh
# Montenegro|President|Milo Đukanović
# Morocco|King|Mohammed VI
# Mozambique|President|Filipe Nyusi
# Myanmar|Chairman of the State Administration Council|Min Aung Hlaing
# President|Prime Minister|Min Aung Hlaing
# Namibia|President|Hage Geingob
# Nauru|President|Russ Kun
# Nepal|President|Bidya Devi Bhandari
# Netherlands|King|Willem-Alexander
# New Zealand|King|Charles III
# Nicaragua|President|Daniel Ortega
# Niger|President|Mohamed Bazoum
# Nigeria|President|Muhammadu Buhari
# North Korea|General Secretary of the Workers' Party|Kim Jong-un
# President of the State Affairs Commission|Premier|Kim Tok-hun
# North Macedonia|President|Stevo Pendarovski
# Norway|King|Harald V
# Oman|Sultan|Prime Minister
# Pakistan|President|Arif Alvi
# Palau|President|Surangel Whipps Jr.
# Palestine|President|Mahmoud Abbas
# Panama|President|Laurentino Cortizo
# Papua New Guinea|King|Charles III
# Paraguay|President|Mario Abdo Benítez
# Peru|President|Dina Boluarte
# Philippines|President|Bongbong Marcos
# Poland|President|Andrzej Duda
# Portugal|President|Marcelo Rebelo de Sousa
# Qatar|Emir|Tamim bin Hamad Al Thani
# Romania|President|Klaus Iohannis
# Russia|President|Vladimir Putin
# Rwanda|President|Paul Kagame
# Saint Kitts and Nevis|King|Charles III
# Saint Lucia|King|Charles III
# Saint Vincent and the Grenadines|King|Charles III
# Samoa|O le Ao o le Malo|Tuimalealiʻifano Vaʻaletoʻa Sualauvi II
# San Marino|Captain Regent|[θ]
# Captain Regent|Captain Regent|[θ]
# São Tomé and Príncipe|President|Carlos Vila Nova
# Saudi Arabia|King|Salman
# Senegal|President|Macky Sall
# Serbia|President|Aleksandar Vučić
# Seychelles|President|Wavel Ramkalawan
# Sierra Leone|President|Julius Maada Bio
# Singapore|President|Halimah Yacob
# Slovakia|President|Zuzana Čaputová
# Slovenia|President|Nataša Pirc Musar
# Solomon Islands|King|Charles III
# Somalia|President|Hassan Sheikh Mohamud
# South Africa|President|Cyril Ramaphosa
# South Korea|President|Yoon Suk-yeol
# South Sudan|President|Salva Kiir Mayardit
# Spain|King|Felipe VI
# Sri Lanka|President|Ranil Wickremesinghe
# Sudan|Chairman of the Transitional Sovereignty Council|Abdel Fattah al-Burhan
# Suriname|President|Chan Santokhi
# Sweden|King|Carl XVI Gustaf
# Switzerland|Federal Council|[ι]
# Members|Federal Council|[ι]
# Syria|President|Bashar al-Assad
# Tajikistan|President|Emomali Rahmon
# Tanzania|President|Samia Suluhu Hassan
# Thailand|King|Vajiralongkorn
# Togo|President|Faure Gnassingbé
# Tonga|King|Tupou VI
# Trinidad and Tobago|President|Paula-Mae Weekes
# Tunisia|President|Kaïs Saïed
# Turkey|President|Recep Tayyip Erdoğan
# Turkmenistan|People's Council|Gurbanguly Berdimuhamedow
# President|People's Council|Gurbanguly Berdimuhamedow
# Tuvalu|King|Charles III
# Uganda|President|Yoweri Museveni
# Ukraine|President|Volodymyr Zelenskyy
# United Arab Emirates|President|Mohamed bin Zayed Al Nahyan
# United Kingdom|King|Charles III
# United States|President|Joe Biden
# Uruguay|President|Luis Lacalle Pou
# Uzbekistan|President|Shavkat Mirziyoyev
# Vanuatu|President|Nikenike Vurobaravu
# Vatican City|Sovereign|Pope Francis
# Venezuela|President|Nicolás Maduro
# Vietnam|General Secretary of the Communist Party|Nguyễn Phú Trọng
# President|Prime Minister|Phạm Minh Chính
# Yemen|Chairman of the Presidential Leadership Council|Rashad al-Alimi
# Zambia|President|Hakainde Hichilema
# Zimbabwe|President|Emmerson Mnangagwa

# %% [markdown]
# ## What is an API?

# %% [markdown]
# **A**pplication
# **P**rogramming
# **I**nterface
#
# **RE**presentation
# **S**tate
# **T**ransfer
# Characteristics
#
# > Ordering at restaurant analogy

# %% [markdown]
# ### Characteristics?
#
# Client-server, typically HTTP-based, stateless server

# %% [markdown]
# ### What representation is DATA found in?

# %% [markdown]
# **J**ava**S**cript **O**bject **N**otation (json)
#
#
# Textual format for structured data
# * [a,b,c] for arrays
# * {‘x’: m, ‘y’: n, ‘z’: o} for objects

# %% [markdown]
# JSON
# * textual description of python (javascript actually) objects
# * arrays and dictionaries
#
# ```
# {
# 'library': [
#            {'title': 'For Whom the Bell Tolls', 'author': 'Ernest Hemingway'},
#            {'title': 'Trump: The Art of the Deal', 'author': 'Good Question'}
#            ]
# }
# ```

# %% [markdown]
# ### The Anatomy Of A Request
#
# It’s important to know that a request is made up of four things:
#
# 1. The endpoint (the URL)
#
# 2. The method (verb: GET, PUT, POST, etc.)
#
# 3. The headers (parameters)
#
# 4. The data (or body)

# %% [markdown]
# 1. The endpoint (or route) is the url you request for
#
# root-endpoint/?
#
# https://api.github.com
#
# 2. The Method is the type of request you send to the server. You can choose from these types below:
#
# a. GET - Used to get resource from server
#
# b. POST - Used to create new resource on server
#
# c. PUT/PATCH - update resource on server
#
# d. DELETE - delete a resource on the server

# %% [markdown]
# ## FLASK
#
# Flask is a micro web framework written in Python. It can create a REST API that allows you to send data, and receive a predictions as a response.

# %% [markdown]
# Now that you are going to be a Data Scientist, you cannot always rely on having your models in Jupyter Notebook.
#
# Jupyter Notebooks are awesome for EDA. However, when you need an application that has a predictive model, you will need to deploy your model elsewhere.
#
# You can try to get the best model possible in a notebook or a script. Once you have decided that you have the best model, you must hand it in a way that the client can run it easily in their infrastructure.
#
# For this purpose you need a tool that can fit in their  infrastructure, preferably in a language that you’re familiar with. This is where you can use Flask. Flask is a micro web framework written in Python. It can create a REST API that allows you to send data, and receive a prediction as a response.

# %% [markdown]
# ## Pros of Flask
# - Easy to understand development: Beginner friendly.
# - It is very flexible and easy: Comes with a template engine too!
# - Testing: Unit testing is possible. (relate to their programming tests)

# %% [markdown]
# ## Cons of Flask
# - Since it is too easy, it allows to use low-quality code creating a "bad web application".
# - Scalability: It can handle every request one at a time. For multiple requests, it will be slow.
# - Modules: Using more modules is seen as a third party involvement which could be a major breach in security and expense.
# - Community support is limited - more support for frameworks such as Django (streamlit is another)

# %% [markdown]
# Let's do an example on how to do an API using our DS models [Boston_Model.ipynb](Boston_Model.ipynb)

# %% [markdown]
# Flask is not the only end point.
#
# Some people prefer using [Streamlit](https://streamlit.io/) and if you have to do a Dashboard, Plotly [Dash](https://plotly.com/dash/)

# %% [markdown]
# In practice, you will deploy a trained model to the cloud (AWS, Azure, GCP)

# %% [markdown]
# Cloud computing benefits:
# - Cost reduction
# - Quick Deployment
# - Flexibility
# - Scalability
# - Security
# - Backups

# %% [markdown]
# ## What is Tmux
#
# tmux’s is a terminal multiplexer.
#
# - Within one terminal window you can open multiple windows and split-views (called “panes” in tmux lingo).
#
# - Each pane contains its own, independently running terminal instance.
#
# - You won't need to open multiple terminal emulator windows.
#
# - You can also create multiple "sessions" of terminal. Allows you attach/detach from terminal instances. Useful when ssh'ing and don't want to maintain the connection. (e.g. running `python app.py`)
#
# - Many shortcuts to remember: [https://tmuxcheatsheet.com/](https://tmuxcheatsheet.com/)
#
# - You can learn more about it [here](https://www.hamvocke.com/blog/a-quick-and-easy-guide-to-tmux/).

# %% [markdown]
# ### Tmux?
#
# Show Tmux and its interactivity for multiple session handling.

# %% [markdown]
# Installing tmux:
# `sudo apt-get install tmux` (Ubuntu and derivatives)
# `brew install tmux` (Mac)

# %% [markdown]
# Useful commands in Tmux
#
#
# - Splitting Panes:
#  - (Ctrl + b) %   (press ctrl+b together, release, type in %)
#
# - Navigating Panes:
#  - (Ctrl + b) + arrows
#
# - new pane below
#  - (Ctrl + b) "
#
# - Exiting a pane:
#  - exit
#
# - Windows
#  - (Ctrl + b) c
#
# - Switch between windows
#  - (Ctrl + b) 0
#  - (Ctrl + b) 1
#
# - Rename Windows
#  - (Ctrl + b) ,
#
# - Sessions
# - Sessions allow you to ssh via terminal, but then keep it running in the background so you don't have to worry about disconnects.
# - ssh into Plato
# - Create new session
#  - tmux new -s name_of_session
#  - (e.g. run htop)
#
# - Detach from session
#  - (Ctrl + b) d
# - View sessions
#  - tmux ls
#
# - Attach to session
#  - tmux attach -t name_of_session
# - Rename session
#  - tmux rename-session new_name_of_session
